# %% [markdown]
# # Easy Inferencing with 🐸 TTS ⚡
#
# #### You want to quicly synthesize speech using Coqui 🐸 TTS model?
#
# 💡: Grab a pre-trained model and use it to synthesize speech using any speaker voice, including yours! ⚡
#
# 🐸 TTS comes with a list of pretrained models and speaker voices. You can even start a local demo server that you can open it on your favorite web browser and 🗣️ .
#
# In this notebook, we will:
# ```
# 1. List available pre-trained 🐸 TTS models
# 2. Run a 🐸 TTS model
# 3. Listen to the synthesized wave 📣
# 4. Run multispeaker 🐸 TTS model
# ```
# So, let's jump right in!

# %% [markdown]
# ## Install 🐸 TTS ⬇️

# %%
! pip install -U pip
! pip install TTS
# Out:
# Requirement already satisfied: pip in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (24.0)
# Requirement already satisfied: TTS in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (0.22.0)
# Requirement already satisfied: cython>=0.29.30 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (3.0.9)
# Requirement already satisfied: scipy>=1.11.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (1.11.4)
# Requirement already satisfied: torch>=2.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (2.2.1)
# Requirement already satisfied: torchaudio in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (2.2.1)
# Requirement already satisfied: soundfile>=0.12.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.12.1)
# Requirement already satisfied: librosa>=0.10.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.10.0)
# Requirement already satisfied: scikit-learn>=1.3.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (1.4.1.post1)
# Requirement already satisfied: inflect>=5.6.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (7.0.0)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (4.66.2)
# Requirement already satisfied: anyascii>=0.3.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.3.2)
# Requirement already satisfied: pyyaml>=6.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (6.0.1)
# Requirement already satisfied: fsspec>=2023.6.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (2024.2.0)
# Requirement already satisfied: aiohttp>=3.8.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (3.9.3)
# Requirement already satisfied: packaging>=23.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (23.2)
# Requirement already satisfied: flask>=2.0.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (3.0.2)
# Requirement already satisfied: pysbd>=0.3.4 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.3.4)
# Requirement already satisfied: umap-learn>=0.5.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.5.6)
# Requirement already satisfied: pandas<2.0,>=1.4 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (1.5.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (3.8.3)
# Requirement already satisfied: trainer>=0.0.32 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.0.36)
# Requirement already satisfied: coqpit>=0.0.16 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.0.17)
# Requirement already satisfied: jieba in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.42.1)
# Requirement already satisfied: pypinyin in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.44.0)
# Requirement already satisfied: hangul-romanize in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.1.0)
# Requirement already satisfied: gruut==2.2.3 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.2.3)
# Requirement already satisfied: jamo in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.4.1)
# Requirement already satisfied: nltk in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (3.8.1)
# Requirement already satisfied: g2pkk>=0.1.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.1.2)
# Requirement already satisfied: bangla in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.0.2)
# Requirement already satisfied: bnnumerizer in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.0.2)
# Requirement already satisfied: bnunicodenormalizer in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.1.6)
# Requirement already satisfied: einops>=0.6.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.7.0)
# Requirement already satisfied: transformers>=4.33.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (4.39.3)
# Requirement already satisfied: encodec>=0.1.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.1.1)
# Requirement already satisfied: unidecode>=1.3.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (1.3.8)
# Requirement already satisfied: num2words in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.5.13)
# Requirement already satisfied: spacy>=3 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy[ja]>=3->TTS) (3.7.4)
# Requirement already satisfied: numpy==1.22.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (1.22.0)
# Requirement already satisfied: numba>=0.57.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from TTS) (0.59.1)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.14.0)
# Requirement already satisfied: dateparser~=1.1.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (0.13.0)
# Requirement already satisfied: gruut-lang-en~=2.0.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.0.0)
# Requirement already satisfied: jsonlines~=1.2.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.2.0)
# Requirement already satisfied: networkx<3.0.0,>=2.5.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.8.8)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (0.9.10)
# Requirement already satisfied: gruut-lang-fr~=2.0.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.0.2)
# Requirement already satisfied: gruut-lang-es~=2.0.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.0.0)
# Requirement already satisfied: gruut-lang-de~=2.0.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (4.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (1.7.0)
# Requirement already satisfied: pydantic>=1.9.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from inflect>=5.6.0->TTS) (2.6.4)
# Requirement already satisfied: typing-extensions in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from inflect>=5.6.0->TTS) (4.10.0)
# Requirement already satisfied: audioread>=2.1.9 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (3.0.1)
# Requirement already satisfied: joblib>=0.14 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (1.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (2.9.0)
# Requirement already satisfied: docopt>=0.6.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from num2words->TTS) (0.6.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from numba>=0.57.0->TTS) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from pandas<2.0,>=1.4->TTS) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from scikit-learn>=1.3.0->TTS) (3.4.0)
# Requirement already satisfied: cffi>=1.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from soundfile>=0.12.0->TTS) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (6.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.31.0)
# Requirement already satisfied: setuptools in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (68.2.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (3.3.0)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy[ja]>=3->TTS) (0.6.8)
# Requirement already satisfied: sudachidict-core>=20211220 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from spacy[ja]>=3->TTS) (20240409)
# Requirement already satisfied: filelock in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from torch>=2.1->TTS) (3.13.1)
# Requirement already satisfied: sympy in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from torch>=2.1->TTS) (1.12)
# Requirement already satisfied: psutil in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from trainer>=0.0.32->TTS) (5.9.8)
# Requirement already satisfied: tensorboard in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from trainer>=0.0.32->TTS) (2.16.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from transformers>=4.33.0->TTS) (0.21.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from transformers>=4.33.0->TTS) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from transformers>=4.33.0->TTS) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from transformers>=4.33.0->TTS) (0.4.2)
# Requirement already satisfied: pynndescent>=0.5 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from umap-learn>=0.5.1->TTS) (0.5.12)
# Requirement already satisfied: pycparser in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.0->TTS) (2.21)
# Requirement already satisfied: tzlocal in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask>=2.0.1->TTS) (2.1.5)
# Requirement already satisfied: six in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from pooch>=1.0->librosa>=0.10.0->TTS) (4.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from pydantic>=1.9.1->inflect>=5.6.0->TTS) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from pydantic>=1.9.1->inflect>=5.6.0->TTS) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy>=3->spacy[ja]>=3->TTS) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy>=3->spacy[ja]>=3->TTS) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS) (0.16.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from sympy->torch>=2.1->TTS) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (1.62.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (3.20.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (0.7.2)

# %% [markdown]
# ## ✅ List available pre-trained 🐸 TTS models
#
# Coqui 🐸TTS comes with a list of pretrained models for different model types (ex: TTS, vocoder), languages, datasets used for training and architectures.
#
# You can either use your own model or the release models under 🐸TTS.
#
# Use `tts --list_models` to find out the availble models.

# %%
! tts --list_models
# Out:
#  Name format: type/language/dataset/model
#  1: tts_models/multilingual/multi-dataset/xtts_v2
#  2: tts_models/multilingual/multi-dataset/xtts_v1.1
#  3: tts_models/multilingual/multi-dataset/your_tts
#  4: tts_models/multilingual/multi-dataset/bark
#  5: tts_models/bg/cv/vits
#  6: tts_models/cs/cv/vits
#  7: tts_models/da/cv/vits
#  8: tts_models/et/cv/vits
#  9: tts_models/ga/cv/vits
#  10: tts_models/en/ek1/tacotron2
#  11: tts_models/en/ljspeech/tacotron2-DDC
#  12: tts_models/en/ljspeech/tacotron2-DDC_ph
#  13: tts_models/en/ljspeech/glow-tts [already downloaded]
#  14: tts_models/en/ljspeech/speedy-speech
#  15: tts_models/en/ljspeech/tacotron2-DCA
#  16: tts_models/en/ljspeech/vits
#  17: tts_models/en/ljspeech/vits--neon
#  18: tts_models/en/ljspeech/fast_pitch
#  19: tts_models/en/ljspeech/overflow
#  20: tts_models/en/ljspeech/neural_hmm
#  21: tts_models/en/vctk/vits [already downloaded]
#  22: tts_models/en/vctk/fast_pitch
#  23: tts_models/en/sam/tacotron-DDC
#  24: tts_models/en/blizzard2013/capacitron-t2-c50
#  25: tts_models/en/blizzard2013/capacitron-t2-c150_v2
#  26: tts_models/en/multi-dataset/tortoise-v2
#  27: tts_models/en/jenny/jenny
#  28: tts_models/es/mai/tacotron2-DDC
#  29: tts_models/es/css10/vits
#  30: tts_models/fr/mai/tacotron2-DDC
#  31: tts_models/fr/css10/vits
#  32: tts_models/uk/mai/glow-tts
#  33: tts_models/uk/mai/vits
#  34: tts_models/zh-CN/baker/tacotron2-DDC-GST
#  35: tts_models/nl/mai/tacotron2-DDC
#  36: tts_models/nl/css10/vits
#  37: tts_models/de/thorsten/tacotron2-DCA
#  38: tts_models/de/thorsten/vits
#  39: tts_models/de/thorsten/tacotron2-DDC
#  40: tts_models/de/css10/vits-neon
#  41: tts_models/ja/kokoro/tacotron2-DDC
#  42: tts_models/tr/common-voice/glow-tts
#  43: tts_models/it/mai_female/glow-tts
#  44: tts_models/it/mai_female/vits
#  45: tts_models/it/mai_male/glow-tts
#  46: tts_models/it/mai_male/vits
#  47: tts_models/ewe/openbible/vits
#  48: tts_models/hau/openbible/vits
#  49: tts_models/lin/openbible/vits
#  50: tts_models/tw_akuapem/openbible/vits
#  51: tts_models/tw_asante/openbible/vits
#  52: tts_models/yor/openbible/vits
#  53: tts_models/hu/css10/vits
#  54: tts_models/el/cv/vits
#  55: tts_models/fi/css10/vits
#  56: tts_models/hr/cv/vits
#  57: tts_models/lt/cv/vits
#  58: tts_models/lv/cv/vits
#  59: tts_models/mt/cv/vits
#  60: tts_models/pl/mai_female/vits
#  61: tts_models/pt/cv/vits
#  62: tts_models/ro/cv/vits
#  63: tts_models/sk/cv/vits
#  64: tts_models/sl/cv/vits
#  65: tts_models/sv/cv/vits
#  66: tts_models/ca/custom/vits
#  67: tts_models/fa/custom/glow-tts
#  68: tts_models/bn/custom/vits-male
#  69: tts_models/bn/custom/vits-female
#  70: tts_models/be/common-voice/glow-tts
#
#  Name format: type/language/dataset/model
#  1: vocoder_models/universal/libri-tts/wavegrad
#  2: vocoder_models/universal/libri-tts/fullband-melgan
#  3: vocoder_models/en/ek1/wavegrad
#  4: vocoder_models/en/ljspeech/multiband-melgan [already downloaded]
#  5: vocoder_models/en/ljspeech/hifigan_v2
#  6: vocoder_models/en/ljspeech/univnet
#  7: vocoder_models/en/blizzard2013/hifigan_v2
#  8: vocoder_models/en/vctk/hifigan_v2
#  9: vocoder_models/en/sam/hifigan_v2
#  10: vocoder_models/nl/mai/parallel-wavegan
#  11: vocoder_models/de/thorsten/wavegrad
#  12: vocoder_models/de/thorsten/fullband-melgan
#  13: vocoder_models/de/thorsten/hifigan_v1
#  14: vocoder_models/ja/kokoro/hifigan_v1
#  15: vocoder_models/uk/mai/multiband-melgan
#  16: vocoder_models/tr/common-voice/hifigan
#  17: vocoder_models/be/common-voice/hifigan
#
#  Name format: type/language/dataset/model
#  1: voice_conversion_models/multilingual/vctk/freevc24

# %% [markdown]
# ## ✅ Run a 🐸 TTS model
#
# #### **First things first**: Using a release model and default vocoder:
#
# You can simply copy the full model name from the list above and use it

# %%
# !tts --text "▁I▁KNOCKED▁AT▁THE▁DOOR▁ON▁THE▁ANCIENT▁SIDE▁OF▁THE▁BUILDING" \
--model_name "tts_models/en/ljspeech/glow-tts" \
--out_path output.wav
# Out:
#  > tts_models/en/ljspeech/glow-tts is already downloaded.
#  > vocoder_models/en/ljspeech/multiband-melgan is already downloaded.
#  > Using model: glow_tts
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.1
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Vocoder Model: multiband_melgan
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:/Users/coldbrew/Library/Application Support/tts/vocoder_models--en--ljspeech--multiband-melgan/scale_stats.npy
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: multiband_melgan_generator
#  > Discriminator Model: melgan_multiscale_discriminator
#  > Text: ▁I▁KNOCKED▁AT▁THE▁DOOR▁ON▁THE▁ANCIENT▁SIDE▁OF▁THE▁BUILDING
#  > Text splitted to sentences.
# ['▁I▁KNOCKED▁AT▁THE▁DOOR▁ON▁THE▁ANCIENT▁SIDE▁OF▁THE▁BUILDING']
#  > Processing time: 0.25274109840393066
#  > Real-time factor: 0.06909518473277464
#  > Saving output to output.wav

# %% [markdown]
# ## 📣 Listen to the synthesized wave 📣

# %%
import IPython
IPython.display.Audio("output.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### **Second things second**:
#
# 🔶 A TTS model can be either trained on a single speaker voice or multispeaker voices. This training choice is directly reflected on the inference ability and the available speaker voices that can be used to synthesize speech.
#
# 🔶 If you want to run a multispeaker model from the released models list, you can first check the speaker ids using `--list_speaker_idx` flag and use this speaker voice to synthesize speech.

# %%
# list the possible speaker IDs.
# !tts --model_name "tts_models/en/vctk/vits" \
--list_speaker_idxs
# Out:
#  > tts_models/en/vctk/vits is already downloaded.
# Traceback (most recent call last):
#   File "/Users/coldbrew/miniconda3/envs/fluent/bin/tts", line 8, in <module>
#     sys.exit(main())
#   File "/Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages/TTS/bin/synthesize.py", line 377, in main
#     model_path, config_path, model_item = manager.download_model(args.model_name)
#   File "/Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages/TTS/utils/manage.py", line 419, in download_model
#     output_model_path, output_config_path = self._find_files(output_path)
#   File "/Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages/TTS/utils/manage.py", line 442, in _find_files
#     raise ValueError(" [!] Model file not found in the output path")
# ValueError:  [!] Model file not found in the output path

# %% [markdown]
# ## 💬 Synthesize speech using speaker ID 💬

# %%
# !tts --text "Trying out specific speaker voice"\
--out_path spkr-out.wav --model_name "tts_models/en/vctk/vits" \
--speaker_idx "p341"
# Out:
#  > tts_models/en/vctk/vits is already downloaded.
# Traceback (most recent call last):
#   File "/Users/coldbrew/miniconda3/envs/fluent/bin/tts", line 8, in <module>
#     sys.exit(main())
#   File "/Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages/TTS/bin/synthesize.py", line 377, in main
#     model_path, config_path, model_item = manager.download_model(args.model_name)
#   File "/Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages/TTS/utils/manage.py", line 419, in download_model
#     output_model_path, output_config_path = self._find_files(output_path)
#   File "/Users/coldbrew/miniconda3/envs/fluent/lib/python3.10/site-packages/TTS/utils/manage.py", line 442, in _find_files
#     raise ValueError(" [!] Model file not found in the output path")
# ValueError:  [!] Model file not found in the output path

# %% [markdown]
# ## 📣 Listen to the synthesized speaker specific wave 📣

# %%
import IPython
IPython.display.Audio("spkr-out.wav")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 import IPython
# ----> 2 IPython.display.Audio("spkr-out.wav")
#
# File ~/miniconda3/envs/fluent/lib/python3.10/site-packages/IPython/lib/display.py:129, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     127 if self.data is not None and not isinstance(self.data, bytes):
#     128     if rate is None:
# --> 129         raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     130     self.data = Audio._make_wav(data, rate, normalize)
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %% [markdown]
# 🔶 If you want to use an external speaker to synthesize speech, you need to supply `--speaker_wav` flag along with an external speaker encoder path and config file, as follows:

# %% [markdown]
# First we need to get the speaker encoder model, its config and a referece `speaker_wav`

# %%
# !wget https://github.com/coqui-ai/TTS/releases/download/speaker_encoder_model/config_se.json
# !wget https://github.com/coqui-ai/TTS/releases/download/speaker_encoder_model/model_se.pth.tar
# !wget https://github.com/coqui-ai/TTS/raw/speaker_encoder_model/tests/data/ljspeech/wavs/LJ001-0001.wav

# %%
# !tts --model_name tts_models/multilingual/multi-dataset/your_tts \
--encoder_path model_se.pth.tar \
--encoder_config config_se.json \
--speaker_wav LJ001-0001.wav \
--text "Are we not allowed to dim the lights so people can see that a bit better?"\
--out_path spkr-out.wav \
--language_idx "en"

# %% [markdown]
# ## 📣 Listen to the synthesized speaker specific wave 📣

# %%
import IPython
IPython.display.Audio("spkr-out.wav")

# %% [markdown]
# ## 🎉 Congratulations! 🎉 You now know how to use a TTS model to synthesize speech!
# Follow up with the next tutorials to learn more adnavced material.
